# %%
# %matplotlib inline
import os
import csv

import matplotlib.pyplot as plt
import torch
from torch import optim
from torch.nn import functional as F
import pandas as pd
import numpy as np

from nbeats_pytorch.model import NBeatsNet 

# split data into batches without bootstrap and shuffling (for testing)
def split(arr, size):
    arrays = []
    while len(arr) > size:
        slice_ = arr[:size]
        arrays.append(slice_)
        arr = arr[size:]
    arrays.append(arr)
    return arrays

# split data into batches with bootstrap
def bootstrap_batch(arr, target, size):
    idx = np.random.choice(len(arr), size, replace=True)
    return arr[idx], target[idx]

# data generator
def batcher(x, y, batch_size, infinite=False):
    if infinite: # training
        while True:
            x_, y_ = bootstrap_batch(x, y, batch_size)
            yield x_, y_
    else: # evaluating
        for x_, y_ in zip(split(x, batch_size), split(y, batch_size)):
            yield x_, y_

# save model to file
def save(model, optimiser, grad_step, checkpoint_name):
    torch.save({
        'grad_step': grad_step,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimiser.state_dict(),
    }, checkpoint_name)

# load model from file
def load(model, checkpoint_name, optimiser=None):
    if os.path.exists(checkpoint_name):
        checkpoint = torch.load(checkpoint_name)
        model.load_state_dict(checkpoint['model_state_dict'])
        if optimiser is not None:
            optimiser.load_state_dict(checkpoint['optimizer_state_dict'])
        grad_step = checkpoint['grad_step']
        print(f'Restored checkpoint from {checkpoint_name}.')
        return grad_step
    return 0

# plots forecast of a model into a file
def plot(net, x, target, backcast_length, forecast_length, grad_step):
    net.eval()
    _, f = net(torch.tensor(x, dtype=torch.float))
    
    fig, ax = plt.subplots(ncols=3, nrows=3, figsize=(8, 8))
    plt.subplots_adjust(top=0.88)
    for i in range(3):
        for j in range(3):
            index = 3 * i + j
            ff, xx, yy = f.cpu().numpy()[index], x[index], target[index]
            ax[i, j].plot(range(0, backcast_length), xx, color='b')
            ax[i, j].plot(range(backcast_length, backcast_length + \
                                forecast_length), yy, color='g')
            ax[i, j].plot(range(backcast_length, backcast_length + \
                                forecast_length), ff, color='r')

    
    output = 'n_beats_{}.png'.format(grad_step)
    plt.savefig(output)
    plt.clf()
    print('Saved image to {}.'.format(output))

# function to load m4 data for training n-beats
def get_m4_data_training(backcast_length, forecast_length, Lh, data_type):
    
    data_type = data_type[0].upper() + data_type[1:]

    x_ts = []
    headers = True
    with open('./data/m4/{}-train.csv'.format(data_type), "r") as file:
        reader = csv.reader(file, delimiter=',')
        for line in reader:
            line = line[1:]
            if not headers:
                x_ts.append(line)
            if headers:
                headers = False
    x_ts_train = np.array(x_ts)
    
    x = np.empty((x_ts_train.shape[0], backcast_length))
    y = np.empty((x_ts_train.shape[0], forecast_length))
    
    for i in range(x_ts_train.shape[0]):
        time_series = np.array(x_ts_train[i])
        time_series = [float(s) for s in time_series if s != '']
        time_series_cleaned = np.array(time_series)
        time_series_cleaned_forlearning_x = np.zeros((1, backcast_length))
        time_series_cleaned_forlearning_y = np.zeros((1, forecast_length))

        # split point
        j = max(int(len(time_series_cleaned) * backcast_length / \
                (backcast_length + forecast_length)), len(time_series_cleaned) - 1 - \
                np.random.randint(0, int(Lh * forecast_length)))
        
        nonzero_input = time_series_cleaned[max(0, j - backcast_length): j]
        time_series_cleaned_forlearning_x[0, -len(nonzero_input):] = nonzero_input
        
        nonzero_target = time_series_cleaned[j:j + forecast_length]
        time_series_cleaned_forlearning_y[0, : len(nonzero_target)] = nonzero_target

        x[i] = time_series_cleaned_forlearning_x
        y[i] = time_series_cleaned_forlearning_y

    print(x.shape, y.shape)
    return x, y

# function to load fred data for training n-beats
def get_fred_data_training(backcast_length, forecast_length, Lh, data_type):
    
    x_ts = []
    with open('./data/fred/{}_final.csv'.format(data_type), "r") as file:
        reader = csv.reader(file, delimiter=',')
        for line in reader:
            ts = np.array(line).astype(float)
            x_ts.append(ts)
            
    x_ts_train = np.array(x_ts)
    
    x = np.empty((x_ts_train.shape[0], backcast_length))
    y = np.empty((x_ts_train.shape[0], forecast_length))
    
    for i in range(x_ts_train.shape[0]):
        
        time_series_cleaned = x_ts_train[i]
        time_series_cleaned_forlearning_x = np.zeros((1, backcast_length))
        time_series_cleaned_forlearning_y = np.zeros((1, forecast_length))

        # split point
        j = max(int(len(time_series_cleaned) * backcast_length / \
                (backcast_length + forecast_length)), len(time_series_cleaned) - 1 - \
                np.random.randint(0, int(Lh * forecast_length)))
        
        nonzero_input = time_series_cleaned[max(0, j - backcast_length): j]
        time_series_cleaned_forlearning_x[0, -len(nonzero_input):] = nonzero_input
        
        nonzero_target = time_series_cleaned[j:j + forecast_length]
        time_series_cleaned_forlearning_y[0, : len(nonzero_target)] = nonzero_target

        x[i] = time_series_cleaned_forlearning_x
        y[i] = time_series_cleaned_forlearning_y

    print(x.shape, y.shape)
    return x, y


# function to load fred data for training n-beats with interpolation
def get_fred_data_training_interpolation(backcast_length, forecast_length, Lh, data_type):
   
    def interpolate(left_point, nonzero_data):
        interpolation = np.empty(len(nonzero_data))
        interpolation[0] = (left_point + nonzero_data[0]) * 0.5
        interpolation[1:] = (nonzero_data[:-1] + nonzero_data[1:]) * 0.5
        return np.insert(nonzero_data, np.arange(len(interpolation)), interpolation)
   
   
    x_ts = []
    with open('./data/fred/{}_final.csv'.format(data_type), "r") as file:
        reader = csv.reader(file, delimiter=',')
        for line in reader:
            ts = np.array(line).astype(float)
            x_ts.append(ts)
           
    x_ts_train = np.array(x_ts)
   
    x = np.empty((x_ts_train.shape[0], backcast_length))
    y = np.empty((x_ts_train.shape[0], forecast_length))
   
    backcast_shape_forlearning = (1, backcast_length)
    forcast_shape_forlearning = (1, forecast_length)
    backcast_length //= 2
    forecast_length //= 2
   
    for i in range(x_ts_train.shape[0]):
       
        time_series_cleaned = x_ts_train[i]
        time_series_cleaned_forlearning_x = np.zeros(backcast_shape_forlearning)
        time_series_cleaned_forlearning_y = np.zeros(forcast_shape_forlearning)
 
        # split point
        j = max(int(len(time_series_cleaned) * backcast_length / \
                (backcast_length + forecast_length)), \
                len(time_series_cleaned) - 1 - \
                np.random.randint(0, int(Lh * forecast_length)))
       
        start = max(0, j - backcast_length)
        left_point_train = 0
        if start > 0:
            left_point_train = time_series_cleaned[start - 1]
        nonzero_input = time_series_cleaned[start: j]
        nonzero_input = interpolate(left_point_train, nonzero_input)
        time_series_cleaned_forlearning_x[0, -len(nonzero_input):] = nonzero_input
       
        nonzero_target = time_series_cleaned[j:j + forecast_length]
        nonzero_target = interpolate(time_series_cleaned[j - 1], nonzero_target)
        time_series_cleaned_forlearning_y[0, : len(nonzero_target)] = nonzero_target
 
        x[i] = time_series_cleaned_forlearning_x
        y[i] = time_series_cleaned_forlearning_y
 
    print(x.shape, y.shape)
    return x, y


# loss function
def smape_loss(output, target):
    nonzero_mask = target != 0
    target = target[nonzero_mask]
    output = output[nonzero_mask]
    
    numerator = torch.abs(output - target)
    denominator = torch.abs(output) + torch.abs(target)
    elementwise_smape = torch.div(numerator, denominator)
        
    nan_mask = torch.isnan(elementwise_smape)
    loss = elementwise_smape[~nan_mask].mean() * 200
    
    return loss

# function to train n-beats
def fit_smape(net, optimiser, data_generator, on_save_callback, device, \
               max_grad_steps, checkpoint_name):
    print('--- Training ---')
    losses = []
    
    net.train()
    initial_grad_step = load(net, checkpoint_name, optimiser)
    for grad_step, (x, target) in enumerate(data_generator):
        
        grad_step += initial_grad_step
        optimiser.zero_grad()
        backcast, forecast = net(torch.tensor(x, dtype=torch.float).to(device))
        loss = smape_loss(forecast, torch.tensor(target, dtype=torch.float).to(device))
        loss.backward()
        optimiser.step()
        if grad_step % 100 == 0:
            print(f'grad_step = {str(grad_step).zfill(6)}, loss = {loss.item():.6f}')
        losses.append(loss.item())
        if grad_step % 500 == 0 or (grad_step < 1000 and grad_step % 200 == 0):
            with torch.no_grad():
                save(net, optimiser, grad_step, checkpoint_name)
        if grad_step > max_grad_steps:
            print('Finished.')
            with torch.no_grad():
                if on_save_callback is not None:
                    on_save_callback(x, target, grad_step)
            break
            
    plt.plot(losses)
    plt.show()
    return losses

# %% [markdown]
# ### Code for training different frequencies on different datasets
#
# Parameters to set:
# - data_type: ('yearly', 'quarterly', 'monthly', 'weekly', 'daily', 'hourly') for M4, ('yearly', 'quarterly', 'monthly') for fred - requency to train on
#
# - dataset: 'm4' or 'fred' - dataset to train on
#
# Saves trained models to a FOLDER (may be changed) into a file CHECKPOINT_NAME

# %%
data_type = 'yearly'
dataset = 'fred'


if data_type == 'yearly':
    forecast_length = 6
    Lh = 1.5
    max_grad_steps = 15000
elif data_type == 'quarterly':
    forecast_length = 8
    Lh = 1.5
    max_grad_steps = 15000
elif data_type == 'monthly':
    forecast_length = 18
    Lh = 1.5
    max_grad_steps = 15000
elif data_type == 'weekly':
    forecast_length = 13
    Lh = 10
    max_grad_steps = 5000
elif data_type == 'daily':
    forecast_length = 14
    Lh = 10
    max_grad_steps = 5000
else: # data_type == 'hourly'
    forecast_length = 48
    Lh = 10
    max_grad_steps = 5000

batch_size = 1024
    
folder = './{}_checkpoints_{}/'.format(dataset, data_type)

for i in range(2, 8):
    print('-------------------------------------')
    print(i)
    
    device = 'cuda:1' if torch.cuda.is_available() else torch.device('cpu')
    backcast_length = i * forecast_length

    if dataset == 'm4':
        x, y = get_m4_data_training(backcast_length, forecast_length, Lh, data_type)
        
        # scaling data for m4 (does not contain negative elements)
        max_consts = x.max(axis=1)
        x_scaled = x.copy()
        for j in range(x.shape[1]):
            x_scaled[:, j] /= max_consts

        y_scaled = y.copy()
        for j in range(y.shape[1]):
            y_scaled[:, j] /= max_consts
        
    else: # dataset == 'fred'
        x, y = get_fred_data_training(backcast_length, forecast_length, Lh, data_type)
        
        max_consts = np.empty(x.shape[0])
        min_consts = np.empty(x.shape[0])
        nonzero_mask = np.ones(x.shape[0], dtype=bool)
        x_scaled = x.copy()
        for j in range(x_scaled.shape[0]):
            ts_nonzero = np.trim_zeros(x_scaled[j], 'f')
            # all-zeros array - drop from training
            if len(ts_nonzero) == 0:
                nonzero_mask[j] = False
                continue
            max_consts[j] = ts_nonzero.max()
            min_consts[j] = ts_nonzero.min()
            # drop ts from learning if it is constant
            if max_consts[j] == min_consts[j]:
                nonzero_mask[j] = False
                continue
            x_scaled[j, -len(ts_nonzero):] = (ts_nonzero - min_consts[j]) / \
                                                 (max_consts[j] - min_consts[j])
    
        x_scaled = x_scaled[nonzero_mask]
        max_consts = max_consts[nonzero_mask]
        min_consts = min_consts[nonzero_mask]
        y_scaled = y.copy()[nonzero_mask]
        for j in range(y_scaled.shape[0]):
            ts_y_nonzero = np.trim_zeros(y_scaled[j], 'b')
            y_scaled[j, :len(ts_y_nonzero)] = (ts_y_nonzero - min_consts[j]) / \
                                                 (max_consts[j] - min_consts[j])
    
    data_gen = batcher(x_scaled, y_scaled, batch_size=batch_size, infinite=True)
    
    checkpoint_name = '{}{}_share_{}H_G_2_smape.th'.\
                            format(folder, data_type[:-2], i)
    
    print('--- Model ---')
    n_stacks = 30
    net = NBeatsNet(device=device,
                    stack_types=[NBeatsNet.GENERIC_BLOCK] * n_stacks,
                    forecast_length=forecast_length,
                    thetas_dims=[4] * n_stacks,
                    nb_blocks_per_stack=1,
                    backcast_length=backcast_length,
                    hidden_layer_units=512,
                    share_weights_in_stack=True
                    )

    optimiser = optim.Adam(net.parameters())

    def plot_model(x, target, grad_step):
        plot(net, x, target, backcast_length, forecast_length, grad_step)

    losses = fit_smape(net, optimiser, data_gen, plot_model, device, \
                              max_grad_steps, checkpoint_name)
# Out:
# -------------------------------------
# 2
# (94093, 12) (94093, 6)
# --- Model ---
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316697657016
# | --  Stack Generic (#1) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316695031144
# | --  Stack Generic (#2) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316695029240
# | --  Stack Generic (#3) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316695031368
# | --  Stack Generic (#4) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316695030192
# | --  Stack Generic (#5) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316695030136
# | --  Stack Generic (#6) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646293800
# | --  Stack Generic (#7) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646294304
# | --  Stack Generic (#8) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646294808
# | --  Stack Generic (#9) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646295312
# | --  Stack Generic (#10) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646295816
# | --  Stack Generic (#11) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646296320
# | --  Stack Generic (#12) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646296824
# | --  Stack Generic (#13) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316646297328
# | --  Stack Generic (#14) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653441320
# | --  Stack Generic (#15) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653441824
# | --  Stack Generic (#16) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653442328
# | --  Stack Generic (#17) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653442832
# | --  Stack Generic (#18) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653443336
# | --  Stack Generic (#19) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653443840
# | --  Stack Generic (#20) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653444344
# | --  Stack Generic (#21) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653444848
# | --  Stack Generic (#22) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653891880
# | --  Stack Generic (#23) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653892384
# | --  Stack Generic (#24) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653892888
# | --  Stack Generic (#25) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653893392
# | --  Stack Generic (#26) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653893896
# | --  Stack Generic (#27) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653894400
# | --  Stack Generic (#28) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653894904
# | --  Stack Generic (#29) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=12, forecast_length=6, share_thetas=False) at @23316653895408
# --- Training ---
# Restored checkpoint from ./fred_checkpoints_yearly/year_share_2H_G_2_smape.th.
# grad_step = 015000, loss = 59.306049
# Finished.
# Saved image to n_beats_15001.png.
# -------------------------------------
# 3
# (94093, 18) (94093, 6)
# --- Model ---
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316647201312
# | --  Stack Generic (#1) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102349768
# | --  Stack Generic (#2) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102194120
# | --  Stack Generic (#3) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102196640
# | --  Stack Generic (#4) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102194680
# | --  Stack Generic (#5) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316646880256
# | --  Stack Generic (#6) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316646882944
# | --  Stack Generic (#7) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316646881992
# | --  Stack Generic (#8) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102126056
# | --  Stack Generic (#9) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102125216
# | --  Stack Generic (#10) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102127512
# | --  Stack Generic (#11) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102124488
# | --  Stack Generic (#12) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316647075064
# | --  Stack Generic (#13) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316647073776
# | --  Stack Generic (#14) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316647072824
# | --  Stack Generic (#15) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316101596664
# | --  Stack Generic (#16) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316101597616
# | --  Stack Generic (#17) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316101598736
# | --  Stack Generic (#18) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316101598008
# | --  Stack Generic (#19) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316101595600
# | --  Stack Generic (#20) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316101595488
# | --  Stack Generic (#21) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316101595264
# | --  Stack Generic (#22) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102378776
# | --  Stack Generic (#23) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102378496
# | --  Stack Generic (#24) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102380008
# | --  Stack Generic (#25) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102378888
# | --  Stack Generic (#26) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102378832
# | --  Stack Generic (#27) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102379280
# | --  Stack Generic (#28) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316102379000
# | --  Stack Generic (#29) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=18, forecast_length=6, share_thetas=False) at @23316646948704
# --- Training ---
# Restored checkpoint from ./fred_checkpoints_yearly/year_share_3H_G_2_smape.th.
# grad_step = 015000, loss = 48.116772
# Finished.
# Saved image to n_beats_15001.png.
# -------------------------------------
# 4
# (94093, 24) (94093, 6)
# --- Model ---
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316653746160
# | --  Stack Generic (#1) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316652098224
# | --  Stack Generic (#2) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316646881600
# | --  Stack Generic (#3) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316646773872
# | --  Stack Generic (#4) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316646774264
# | --  Stack Generic (#5) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651834616
# | --  Stack Generic (#6) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651018728
# | --  Stack Generic (#7) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651020240
# | --  Stack Generic (#8) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316102218360
# | --  Stack Generic (#9) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316102218416
# | --  Stack Generic (#10) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316644712344
# | --  Stack Generic (#11) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316644710328
# | --  Stack Generic (#12) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316644709768
# | --  Stack Generic (#13) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316644712400
# | --  Stack Generic (#14) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316644708704
# | --  Stack Generic (#15) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316644710216
# | --  Stack Generic (#16) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316644710496
# | --  Stack Generic (#17) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316653781736
# | --  Stack Generic (#18) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316653782688
# | --  Stack Generic (#19) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316653781232
# | --  Stack Generic (#20) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316653784872
# | --  Stack Generic (#21) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316653783976
# | --  Stack Generic (#22) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316653782296
# | --  Stack Generic (#23) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651065808
# | --  Stack Generic (#24) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651067488
# | --  Stack Generic (#25) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651068664
# | --  Stack Generic (#26) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651068552
# | --  Stack Generic (#27) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316102194344
# | --  Stack Generic (#28) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651339112
# | --  Stack Generic (#29) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=24, forecast_length=6, share_thetas=False) at @23316651335752
# --- Training ---
# Restored checkpoint from ./fred_checkpoints_yearly/year_share_4H_G_2_smape.th.
# grad_step = 008000, loss = 47.071854
# grad_step = 008100, loss = 48.859844
# grad_step = 008200, loss = 46.186485
# grad_step = 008300, loss = 43.566029
# grad_step = 008400, loss = 41.189270
# grad_step = 008500, loss = 47.299225
# grad_step = 008600, loss = 41.932552
# grad_step = 008700, loss = 45.633888
# grad_step = 008800, loss = 42.921932
# grad_step = 008900, loss = 41.721107
# grad_step = 009000, loss = 44.806751
# grad_step = 009100, loss = 42.010326
# grad_step = 009200, loss = 42.652615
# grad_step = 009300, loss = 42.392872
# grad_step = 009400, loss = 41.607307
# grad_step = 009500, loss = 41.358822
# grad_step = 009600, loss = 44.086369
# grad_step = 009700, loss = 45.261055
# grad_step = 009800, loss = 42.903038
# grad_step = 009900, loss = 40.953510
# grad_step = 010000, loss = 41.631344
# grad_step = 010100, loss = 41.964451
# grad_step = 010200, loss = 42.054829
# grad_step = 010300, loss = 43.991547
# grad_step = 010400, loss = 43.954117
# grad_step = 010500, loss = 46.394196
# grad_step = 010600, loss = 43.925484
# grad_step = 010700, loss = 41.463158
# grad_step = 010800, loss = 41.224442
# grad_step = 010900, loss = 41.568325
# grad_step = 011000, loss = 41.894176
# grad_step = 011100, loss = 44.582954
# grad_step = 011200, loss = 43.563210
# grad_step = 011300, loss = 40.360268
# grad_step = 011400, loss = 40.768261
# grad_step = 011500, loss = 40.392502
# grad_step = 011600, loss = 39.743557
# grad_step = 011700, loss = 42.558712
# grad_step = 011800, loss = 42.899834
# grad_step = 011900, loss = 40.673874
# grad_step = 012000, loss = 41.700138
# grad_step = 012100, loss = 41.344917
# grad_step = 012200, loss = 41.800705
# grad_step = 012300, loss = 43.131630
# grad_step = 012400, loss = 42.312401
# grad_step = 012500, loss = 42.620953
# grad_step = 012600, loss = 42.270321
# grad_step = 012700, loss = 43.770855
# grad_step = 012800, loss = 41.352116
# grad_step = 012900, loss = 44.465450
# grad_step = 013000, loss = 40.259052
# grad_step = 013100, loss = 43.754719
# grad_step = 013200, loss = 42.808601
# grad_step = 013300, loss = 42.541489
# grad_step = 013400, loss = 42.172249
# grad_step = 013500, loss = 40.378456
# grad_step = 013600, loss = 39.122292
# grad_step = 013700, loss = 39.150440
# grad_step = 013800, loss = 39.299316
# grad_step = 013900, loss = 39.434113
# grad_step = 014000, loss = 39.932037
# grad_step = 014100, loss = 40.428429
# grad_step = 014200, loss = 41.411060
# grad_step = 014300, loss = 39.544777
# grad_step = 014400, loss = 38.993801
# grad_step = 014500, loss = 41.028206
# grad_step = 014600, loss = 39.942276
# grad_step = 014700, loss = 41.793026
# grad_step = 014800, loss = 38.366669
# grad_step = 014900, loss = 40.027790
# grad_step = 015000, loss = 40.685108
# Finished.
# Saved image to n_beats_15001.png.
# -------------------------------------
# 5
# (94093, 30) (94093, 6)
# --- Model ---
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316102218864
# | --  Stack Generic (#1) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316651019736
# | --  Stack Generic (#2) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645918312
# | --  Stack Generic (#3) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316644675032
# | --  Stack Generic (#4) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645629680
# | --  Stack Generic (#5) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645627776
# | --  Stack Generic (#6) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645629904
# | --  Stack Generic (#7) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316101814872
# | --  Stack Generic (#8) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316101815600
# | --  Stack Generic (#9) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650041584
# | --  Stack Generic (#10) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650043656
# | --  Stack Generic (#11) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650044328
# | --  Stack Generic (#12) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645579800
# | --  Stack Generic (#13) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645579072
# | --  Stack Generic (#14) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645576944
# | --  Stack Generic (#15) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645580192
# | --  Stack Generic (#16) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645577224
# | --  Stack Generic (#17) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650002304
# | --  Stack Generic (#18) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650001520
# | --  Stack Generic (#19) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650000848
# | --  Stack Generic (#20) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650003032
# | --  Stack Generic (#21) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650003480
# | --  Stack Generic (#22) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316650002864
# | --  Stack Generic (#23) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645507816
# | --  Stack Generic (#24) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645507760
# | --  Stack Generic (#25) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645508264
# | --  Stack Generic (#26) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645510448
# | --  Stack Generic (#27) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316645507424
# | --  Stack Generic (#28) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316644700960
# | --  Stack Generic (#29) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=30, forecast_length=6, share_thetas=False) at @23316644701016
# --- Training ---
# grad_step = 000000, loss = 120.462334
# grad_step = 000100, loss = 50.518173
# grad_step = 000200, loss = 51.648731
# grad_step = 000300, loss = 49.466427
# grad_step = 000400, loss = 47.355194
# grad_step = 000500, loss = 45.489403
# grad_step = 000600, loss = 44.673203
# grad_step = 000700, loss = 46.952171
# grad_step = 000800, loss = 48.199364
# grad_step = 000900, loss = 47.909161
# grad_step = 001000, loss = 44.607052
# grad_step = 001100, loss = 45.105824
# grad_step = 001200, loss = 43.772179
# grad_step = 001300, loss = 45.381634
# grad_step = 001400, loss = 42.096729
# grad_step = 001500, loss = 45.165321
# grad_step = 001600, loss = 44.529766
# grad_step = 001700, loss = 44.343704
# grad_step = 001800, loss = 45.857979
# grad_step = 001900, loss = 42.043930
# grad_step = 002000, loss = 43.320362
# grad_step = 002100, loss = 43.620403
# grad_step = 002200, loss = 44.091328
# grad_step = 002300, loss = 42.164890
# grad_step = 002400, loss = 42.468937
# grad_step = 002500, loss = 43.760254
# grad_step = 002600, loss = 45.017902
# grad_step = 002700, loss = 43.981007
# grad_step = 002800, loss = 43.484425
# grad_step = 002900, loss = 45.574905
# grad_step = 003000, loss = 47.047184
# grad_step = 003100, loss = 42.816429
# grad_step = 003200, loss = 45.892868
# grad_step = 003300, loss = 44.866478
# grad_step = 003400, loss = 44.841309
# grad_step = 003500, loss = 44.533657
# grad_step = 003600, loss = 49.782307
# grad_step = 003700, loss = 46.513626
# grad_step = 003800, loss = 42.102959
# grad_step = 003900, loss = 41.230946
# grad_step = 004000, loss = 41.126640
# grad_step = 004100, loss = 43.301792
# grad_step = 004200, loss = 43.106140
# grad_step = 004300, loss = 40.543068
# grad_step = 004400, loss = 43.109550
# grad_step = 004500, loss = 45.274090
# grad_step = 004600, loss = 42.557022
# grad_step = 004700, loss = 41.755424
# grad_step = 004800, loss = 42.117508
# grad_step = 004900, loss = 40.967804
# grad_step = 005000, loss = 43.652267
# grad_step = 005100, loss = 42.515270
# grad_step = 005200, loss = 43.064484
# grad_step = 005300, loss = 41.351521
# grad_step = 005400, loss = 45.543102
# grad_step = 005500, loss = 45.949451
# grad_step = 005600, loss = 45.565411
# grad_step = 005700, loss = 43.914894
# grad_step = 005800, loss = 41.701923
# grad_step = 005900, loss = 41.232265
# grad_step = 006000, loss = 43.879475
# grad_step = 006100, loss = 44.124786
# grad_step = 006200, loss = 42.901264
# grad_step = 006300, loss = 45.092941
# grad_step = 006400, loss = 43.182476
# grad_step = 006500, loss = 42.878361
# grad_step = 006600, loss = 45.603451
# grad_step = 006700, loss = 39.399727
# grad_step = 006800, loss = 41.677917
# grad_step = 006900, loss = 40.801109
# grad_step = 007000, loss = 43.854897
# grad_step = 007100, loss = 43.540863
# grad_step = 007200, loss = 43.602139
# grad_step = 007300, loss = 41.326088
# grad_step = 007400, loss = 44.982037
# grad_step = 007500, loss = 42.734997
# grad_step = 007600, loss = 43.190010
# grad_step = 007700, loss = 43.616119
# grad_step = 007800, loss = 43.169041
# grad_step = 007900, loss = 41.500813
# grad_step = 008000, loss = 39.770855
# grad_step = 008100, loss = 46.977600
# grad_step = 008200, loss = 44.194702
# grad_step = 008300, loss = 42.664482
# grad_step = 008400, loss = 42.525532
# grad_step = 008500, loss = 41.669296
# grad_step = 008600, loss = 38.776100
# grad_step = 008700, loss = 41.075108
# grad_step = 008800, loss = 40.107273
# grad_step = 008900, loss = 38.827488
# grad_step = 009000, loss = 43.025703
# grad_step = 009100, loss = 41.558395
# grad_step = 009200, loss = 44.811325
# grad_step = 009300, loss = 41.454624
# grad_step = 009400, loss = 39.933853
# grad_step = 009500, loss = 42.006508
# grad_step = 009600, loss = 42.076790
# grad_step = 009700, loss = 44.168400
# grad_step = 009800, loss = 44.403210
# grad_step = 009900, loss = 44.464336
# grad_step = 010000, loss = 40.494286
# grad_step = 010100, loss = 42.470303
# grad_step = 010200, loss = 39.554760
# grad_step = 010300, loss = 45.127480
# grad_step = 010400, loss = 39.495861
# grad_step = 010500, loss = 41.832050
# grad_step = 010600, loss = 40.801353
# grad_step = 010700, loss = 38.085938
# grad_step = 010800, loss = 40.093548
# grad_step = 010900, loss = 40.455513
# grad_step = 011000, loss = 39.872681
# grad_step = 011100, loss = 39.359070
# grad_step = 011200, loss = 40.914501
# grad_step = 011300, loss = 42.341225
# grad_step = 011400, loss = 40.719009
# grad_step = 011500, loss = 39.753826
# grad_step = 011600, loss = 40.928703
# grad_step = 011700, loss = 40.227543
# grad_step = 011800, loss = 38.855080
# grad_step = 011900, loss = 44.480206
# grad_step = 012000, loss = 39.962852
# grad_step = 012100, loss = 40.272522
# grad_step = 012200, loss = 38.744144
# grad_step = 012300, loss = 40.814434
# grad_step = 012400, loss = 38.513149
# grad_step = 012500, loss = 38.988094
# grad_step = 012600, loss = 40.384113
# grad_step = 012700, loss = 39.643574
# grad_step = 012800, loss = 41.371338
# grad_step = 012900, loss = 37.088989
# grad_step = 013000, loss = 40.904671
# grad_step = 013100, loss = 40.458881
# grad_step = 013200, loss = 36.083588
# grad_step = 013300, loss = 40.498550
# grad_step = 013400, loss = 39.608074
# grad_step = 013500, loss = 40.316086
# grad_step = 013600, loss = 37.270897
# grad_step = 013700, loss = 37.796516
# grad_step = 013800, loss = 37.658981
# grad_step = 013900, loss = 38.436638
# grad_step = 014000, loss = 32.744358
# grad_step = 014100, loss = 39.312927
# grad_step = 014200, loss = 37.773548
# grad_step = 014300, loss = 39.534515
# grad_step = 014400, loss = 39.534554
# grad_step = 014500, loss = 39.690582
# grad_step = 014600, loss = 36.890400
# grad_step = 014700, loss = 40.586586
# grad_step = 014800, loss = 40.569942
# grad_step = 014900, loss = 34.582417
# grad_step = 015000, loss = 36.535175
# Finished.
# Saved image to n_beats_15001.png.
# -------------------------------------
# 6
# (94093, 36) (94093, 6)
# --- Model ---
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316102221776
# | --  Stack Generic (#1) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316647200920
# | --  Stack Generic (#2) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316650554592
# | --  Stack Generic (#3) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316102355824
# | --  Stack Generic (#4) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316102059400
# | --  Stack Generic (#5) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651213096
# | --  Stack Generic (#6) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651216176
# | --  Stack Generic (#7) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651213264
# | --  Stack Generic (#8) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651216008
# | --  Stack Generic (#9) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651193232
# | --  Stack Generic (#10) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316101907736
# | --  Stack Generic (#11) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316101908072
# | --  Stack Generic (#12) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649724336
# | --  Stack Generic (#13) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649722040
# | --  Stack Generic (#14) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649725400
# | --  Stack Generic (#15) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649819776
# | --  Stack Generic (#16) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649817424
# | --  Stack Generic (#17) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649819552
# | --  Stack Generic (#18) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649817480
# | --  Stack Generic (#19) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649816248
# | --  Stack Generic (#20) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649816808
# | --  Stack Generic (#21) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316649818264
# | --  Stack Generic (#22) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651695520
# | --  Stack Generic (#23) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651695800
# | --  Stack Generic (#24) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651693448
# | --  Stack Generic (#25) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651694456
# | --  Stack Generic (#26) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651692608
# | --  Stack Generic (#27) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316651696024
# | --  Stack Generic (#28) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316101901504
# | --  Stack Generic (#29) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=36, forecast_length=6, share_thetas=False) at @23316101900608
# --- Training ---
# grad_step = 000000, loss = 188.825302
# grad_step = 000100, loss = 49.338566
# grad_step = 000200, loss = 48.023575
# grad_step = 000300, loss = 44.339024
# grad_step = 000400, loss = 41.885399
# grad_step = 000500, loss = 45.671505
# grad_step = 000600, loss = 46.147999
# grad_step = 000700, loss = 48.566032
# grad_step = 000800, loss = 46.375957
# grad_step = 000900, loss = 47.961922
# grad_step = 001000, loss = 43.220264
# grad_step = 001100, loss = 44.569778
# grad_step = 001200, loss = 45.245205
# grad_step = 001300, loss = 41.224377
# grad_step = 001400, loss = 41.134140
# grad_step = 001500, loss = 42.525299
# grad_step = 001600, loss = 45.024796
# grad_step = 001700, loss = 42.089458
# grad_step = 001800, loss = 45.474064
# grad_step = 001900, loss = 41.844067
# grad_step = 002000, loss = 41.484764
# grad_step = 002100, loss = 43.279671
# grad_step = 002200, loss = 43.480831
# grad_step = 002300, loss = 45.392113
# grad_step = 002400, loss = 42.143040
# grad_step = 002500, loss = 39.027962
# grad_step = 002600, loss = 40.851887
# grad_step = 002700, loss = 44.185181
# grad_step = 002800, loss = 42.381073
# grad_step = 002900, loss = 40.199806
# grad_step = 003000, loss = 42.207901
# grad_step = 003100, loss = 40.208382
# grad_step = 003200, loss = 41.453747
# grad_step = 003300, loss = 43.055508
# grad_step = 003400, loss = 40.279610
# grad_step = 003500, loss = 41.979401
# grad_step = 003600, loss = 40.956245
# grad_step = 003700, loss = 39.962414
# grad_step = 003800, loss = 44.709888
# grad_step = 003900, loss = 40.533283
# grad_step = 004000, loss = 41.921543
# grad_step = 004100, loss = 43.771084
# grad_step = 004200, loss = 36.602654
# grad_step = 004300, loss = 42.021824
# grad_step = 004400, loss = 38.149055
# grad_step = 004500, loss = 41.741207
# grad_step = 004600, loss = 43.149670
# grad_step = 004700, loss = 43.128059
# grad_step = 004800, loss = 37.470470
# grad_step = 004900, loss = 39.205502
# grad_step = 005000, loss = 40.517052
# grad_step = 005100, loss = 40.550896
# grad_step = 005200, loss = 38.417606
# grad_step = 005300, loss = 39.804119
# grad_step = 005400, loss = 36.290081
# grad_step = 005500, loss = 41.853790
# grad_step = 005600, loss = 39.315651
# grad_step = 005700, loss = 39.786034
# grad_step = 005800, loss = 41.368546
# grad_step = 005900, loss = 39.175850
# grad_step = 006000, loss = 38.971596
# grad_step = 006100, loss = 39.184875
# grad_step = 006200, loss = 39.630737
# grad_step = 006300, loss = 40.205036
# grad_step = 006400, loss = 39.488594
# grad_step = 006500, loss = 37.037476
# grad_step = 006600, loss = 38.107384
# grad_step = 006700, loss = 36.382866
# grad_step = 006800, loss = 38.358681
# grad_step = 006900, loss = 39.454285
# grad_step = 007000, loss = 38.438705
# grad_step = 007100, loss = 37.518005
# grad_step = 007200, loss = 37.513672
# grad_step = 007300, loss = 38.071083
# grad_step = 007400, loss = 36.957615
# grad_step = 007500, loss = 38.569492
# grad_step = 007600, loss = 40.143936
# grad_step = 007700, loss = 38.745003
# grad_step = 007800, loss = 38.704582
# grad_step = 007900, loss = 37.734112
# grad_step = 008000, loss = 34.908909
# grad_step = 008100, loss = 38.411068
# grad_step = 008200, loss = 36.987270
# grad_step = 008300, loss = 35.390526
# grad_step = 008400, loss = 34.095226
# grad_step = 008500, loss = 37.795532
# grad_step = 008600, loss = 40.053780
# grad_step = 008700, loss = 40.988503
# grad_step = 008800, loss = 38.229996
# grad_step = 008900, loss = 39.697262
# grad_step = 009000, loss = 35.967270
# grad_step = 009100, loss = 39.504852
# grad_step = 009200, loss = 36.526279
# grad_step = 009300, loss = 36.364834
# grad_step = 009400, loss = 36.537712
# grad_step = 009500, loss = 37.619114
# grad_step = 009600, loss = 34.247242
# grad_step = 009700, loss = 37.442036
# grad_step = 009800, loss = 36.048252
# grad_step = 009900, loss = 37.909447
# grad_step = 010000, loss = 34.943996
# grad_step = 010100, loss = 32.584061
# grad_step = 010200, loss = 38.713039
# grad_step = 010300, loss = 37.811501
# grad_step = 010400, loss = 33.311954
# grad_step = 010500, loss = 35.403679
# grad_step = 010600, loss = 37.703152
# grad_step = 010700, loss = 37.211887
# grad_step = 010800, loss = 34.765335
# grad_step = 010900, loss = 36.126614
# grad_step = 011000, loss = 35.632622
# grad_step = 011100, loss = 33.507778
# grad_step = 011200, loss = 35.720913
# grad_step = 011300, loss = 34.805275
# grad_step = 011400, loss = 36.753567
# grad_step = 011500, loss = 37.926968
# grad_step = 011600, loss = 38.538174
# grad_step = 011700, loss = 33.422108
# grad_step = 011800, loss = 32.327591
# grad_step = 011900, loss = 34.897999
# grad_step = 012000, loss = 37.969475
# grad_step = 012100, loss = 36.173515
# grad_step = 012200, loss = 34.169872
# grad_step = 012300, loss = 37.173275
# grad_step = 012400, loss = 35.990837
# grad_step = 012500, loss = 39.083920
# grad_step = 012600, loss = 36.926941
# grad_step = 012700, loss = 35.181355
# grad_step = 012800, loss = 34.188782
# grad_step = 012900, loss = 37.859013
# grad_step = 013000, loss = 33.091282
# grad_step = 013100, loss = 35.830944
# grad_step = 013200, loss = 34.864685
# grad_step = 013300, loss = 34.349010
# grad_step = 013400, loss = 34.973030
# grad_step = 013500, loss = 36.253036
# grad_step = 013600, loss = 33.400303
# grad_step = 013700, loss = 34.958611
# grad_step = 013800, loss = 34.641315
# grad_step = 013900, loss = 34.216656
# grad_step = 014000, loss = 34.704300
# grad_step = 014100, loss = 35.396420
# grad_step = 014200, loss = 35.115311
# grad_step = 014300, loss = 34.088264
# grad_step = 014400, loss = 33.934334
# grad_step = 014500, loss = 33.926331
# grad_step = 014600, loss = 36.503254
# grad_step = 014700, loss = 32.369923
# grad_step = 014800, loss = 31.760984
# grad_step = 014900, loss = 36.002304
# grad_step = 015000, loss = 32.782120
# Finished.
# Saved image to n_beats_15001.png.
# -------------------------------------
# 7
# (94093, 42) (94093, 6)
# --- Model ---
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316101815544
# | --  Stack Generic (#1) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316651017272
# | --  Stack Generic (#2) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316064378216
# | --  Stack Generic (#3) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316645383248
# | --  Stack Generic (#4) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316651216512
# | --  Stack Generic (#5) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316651097336
# | --  Stack Generic (#6) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316651094312
# | --  Stack Generic (#7) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316064627176
# | --  Stack Generic (#8) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316064625832
# | --  Stack Generic (#9) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316645588328
# | --  Stack Generic (#10) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650070872
# | --  Stack Generic (#11) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650070928
# | --  Stack Generic (#12) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650070200
# | --  Stack Generic (#13) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650072384
# | --  Stack Generic (#14) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650103080
# | --  Stack Generic (#15) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650106048
# | --  Stack Generic (#16) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650104200
# | --  Stack Generic (#17) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650104480
# | --  Stack Generic (#18) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650103304
# | --  Stack Generic (#19) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650106384
# | --  Stack Generic (#20) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650105320
# | --  Stack Generic (#21) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316650103024
# | --  Stack Generic (#22) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644770368
# | --  Stack Generic (#23) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644771544
# | --  Stack Generic (#24) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644773784
# | --  Stack Generic (#25) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644771824
# | --  Stack Generic (#26) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644672120
# | --  Stack Generic (#27) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644674752
# | --  Stack Generic (#28) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644673576
# | --  Stack Generic (#29) (share_weights_in_stack=True)
#      | -- GenericBlock(units=512, thetas_dim=4, backcast_length=42, forecast_length=6, share_thetas=False) at @23316644675200
# --- Training ---
# grad_step = 000000, loss = 142.046814
# grad_step = 000100, loss = 52.900909
# grad_step = 000200, loss = 52.968925
# grad_step = 000300, loss = 45.069603
# grad_step = 000400, loss = 44.301929
# grad_step = 000500, loss = 42.260197
# grad_step = 000600, loss = 43.921013
# grad_step = 000700, loss = 44.819355
# grad_step = 000800, loss = 41.704376
# grad_step = 000900, loss = 45.756714
# grad_step = 001000, loss = 40.079803
# grad_step = 001100, loss = 71.137436
# grad_step = 001200, loss = 47.607567
# grad_step = 001300, loss = 44.815323
# grad_step = 001400, loss = 42.117882
# grad_step = 001500, loss = 53.241890
# grad_step = 001600, loss = 43.788563
# grad_step = 001700, loss = 37.934975
# grad_step = 001800, loss = 45.287312
# grad_step = 001900, loss = 40.294884
# grad_step = 002000, loss = 52.200897
# grad_step = 002100, loss = 43.492870
# grad_step = 002200, loss = 40.370644
# grad_step = 002300, loss = 43.823444
# grad_step = 002400, loss = 40.932186
# grad_step = 002500, loss = 41.461220
# grad_step = 002600, loss = 42.296253
# grad_step = 002700, loss = 41.028873
# grad_step = 002800, loss = 47.475304
# grad_step = 002900, loss = 40.746357
# grad_step = 003000, loss = 43.973530
# grad_step = 003100, loss = 39.350708
# grad_step = 003200, loss = 40.209332
# grad_step = 003300, loss = 41.366047
# grad_step = 003400, loss = 38.952999
# grad_step = 003500, loss = 43.043957
# grad_step = 003600, loss = 43.054932
# grad_step = 003700, loss = 37.163277
# grad_step = 003800, loss = 42.443905
# grad_step = 003900, loss = 39.906746
# grad_step = 004000, loss = 36.971741
# grad_step = 004100, loss = 38.634148
# grad_step = 004200, loss = 40.983116
# grad_step = 004300, loss = 43.360302
# grad_step = 004400, loss = 40.729599
# grad_step = 004500, loss = 38.169640
# grad_step = 004600, loss = 42.814571
# grad_step = 004700, loss = 36.028820
# grad_step = 004800, loss = 40.256084
# grad_step = 004900, loss = 38.656189
# grad_step = 005000, loss = 40.456181
# grad_step = 005100, loss = 37.865768
# grad_step = 005200, loss = 43.213070
# grad_step = 005300, loss = 42.466892
# grad_step = 005400, loss = 40.039028
# grad_step = 005500, loss = 38.459248
# grad_step = 005600, loss = 39.648308
# grad_step = 005700, loss = 40.384121
# grad_step = 005800, loss = 41.312019
# grad_step = 005900, loss = 41.468258
# grad_step = 006000, loss = 37.196293
# grad_step = 006100, loss = 40.076656
# grad_step = 006200, loss = 39.620937
# grad_step = 006300, loss = 38.912128
# grad_step = 006400, loss = 37.458057
# grad_step = 006500, loss = 36.554916
# grad_step = 006600, loss = 38.799351
# grad_step = 006700, loss = 40.127270
# grad_step = 006800, loss = 41.219334
# grad_step = 006900, loss = 41.407715
# grad_step = 007000, loss = 41.042892
# grad_step = 007100, loss = 39.614647
# grad_step = 007200, loss = 40.124268
# grad_step = 007300, loss = 41.907322
# grad_step = 007400, loss = 36.428463
# grad_step = 007500, loss = 38.404026
# grad_step = 007600, loss = 41.624527
# grad_step = 007700, loss = 40.354641
# grad_step = 007800, loss = 41.434330
# grad_step = 007900, loss = 39.681404
# grad_step = 008000, loss = 37.565983
# grad_step = 008100, loss = 38.452919
# grad_step = 008200, loss = 39.623417
# grad_step = 008300, loss = 44.278236
# grad_step = 008400, loss = 42.567879
# grad_step = 008500, loss = 43.894501
# grad_step = 008600, loss = 39.532314
# grad_step = 008700, loss = 40.811832
# grad_step = 008800, loss = 38.242401
# grad_step = 008900, loss = 38.438953
# grad_step = 009000, loss = 37.107323
# grad_step = 009100, loss = 39.906101
# grad_step = 009200, loss = 40.532253
# grad_step = 009300, loss = 37.348122
# grad_step = 009400, loss = 41.462971
# grad_step = 009500, loss = 40.503956
# grad_step = 009600, loss = 40.854710
# grad_step = 009700, loss = 38.531570
# grad_step = 009800, loss = 40.506382
# grad_step = 009900, loss = 39.557575
# grad_step = 010000, loss = 38.947971
# grad_step = 010100, loss = 39.955635
# grad_step = 010200, loss = 40.810013
# grad_step = 010300, loss = 40.619064
# grad_step = 010400, loss = 39.631588
# grad_step = 010500, loss = 36.383095
# grad_step = 010600, loss = 37.222755
# grad_step = 010700, loss = 40.655235
# grad_step = 010800, loss = 40.781414
# grad_step = 010900, loss = 45.528099
# grad_step = 011000, loss = 43.970291
# grad_step = 011100, loss = 43.083858
# grad_step = 011200, loss = 36.531010
# grad_step = 011300, loss = 41.770023
# grad_step = 011400, loss = 37.126640
# grad_step = 011500, loss = 37.194382
# grad_step = 011600, loss = 42.031281
# grad_step = 011700, loss = 41.304359
# grad_step = 011800, loss = 39.472935
# grad_step = 011900, loss = 42.010384
# grad_step = 012000, loss = 38.249767
# grad_step = 012100, loss = 40.348152
# grad_step = 012200, loss = 38.683830
# grad_step = 012300, loss = 42.538200
# grad_step = 012400, loss = 37.808205
# grad_step = 012500, loss = 38.548584
# grad_step = 012600, loss = 39.595680
# grad_step = 012700, loss = 36.625923
# grad_step = 012800, loss = 37.535469
# grad_step = 012900, loss = 38.839619
# grad_step = 013000, loss = 39.546749
# grad_step = 013100, loss = 41.469799
# grad_step = 013200, loss = 40.704433
# grad_step = 013300, loss = 42.984470
# grad_step = 013400, loss = 36.886051
# grad_step = 013500, loss = 36.506134
# grad_step = 013600, loss = 37.334206
# grad_step = 013700, loss = 35.628815
# grad_step = 013800, loss = 38.799671
# grad_step = 013900, loss = 38.481049
# grad_step = 014000, loss = 37.241589
# grad_step = 014100, loss = 39.569164
# grad_step = 014200, loss = 40.542339
# grad_step = 014300, loss = 37.009933
# grad_step = 014400, loss = 40.764912
# grad_step = 014500, loss = 39.474812
# grad_step = 014600, loss = 36.847912
# grad_step = 014700, loss = 41.474689
# grad_step = 014800, loss = 41.232349
# grad_step = 014900, loss = 38.676933
# grad_step = 015000, loss = 39.225342
# Finished.
# Saved image to n_beats_15001.png.

# %% [markdown]
# ### Code to train FRED on interpolated monthly data
# It is for prediction on hourly data using FRED

# %%
data_type = 'monthly'
dataset = 'fred'

forecast_length = 18
Lh = 1.5
max_grad_steps = 15000

batch_size = 1024
    
folder = './{}_checkpoints_{}/'.format(dataset, data_type)

for i in range(2, 8):
    print('-------------------------------------')
    print(i)
    
    device = 'cuda:1' if torch.cuda.is_available() else torch.device('cpu')
    backcast_length = i * forecast_length

    x, y = get_fred_data_training_interpolation(backcast_length, \
                    forecast_length, Lh, data_type)

    max_consts = np.empty(x.shape[0])
    min_consts = np.empty(x.shape[0])
    nonzero_mask = np.ones(x.shape[0], dtype=bool)
    x_scaled = x.copy()
    for j in range(x_scaled.shape[0]):
        ts_nonzero = np.trim_zeros(x_scaled[j], 'f')
        # all-zeros array - drop from training
        if len(ts_nonzero) == 0:
            nonzero_mask[j] = False
            continue
        max_consts[j] = ts_nonzero.max()
        min_consts[j] = ts_nonzero.min()
        # drop ts from learning if it is constant
        if max_consts[j] == min_consts[j]:
            nonzero_mask[j] = False
            continue
        x_scaled[j, -len(ts_nonzero):] = (ts_nonzero - min_consts[j]) / \
                                             (max_consts[j] - min_consts[j])

    x_scaled = x_scaled[nonzero_mask]
    max_consts = max_consts[nonzero_mask]
    min_consts = min_consts[nonzero_mask]
    y_scaled = y.copy()[nonzero_mask]
    for j in range(y_scaled.shape[0]):
        ts_y_nonzero = np.trim_zeros(y_scaled[j], 'b')
        y_scaled[j, :len(ts_y_nonzero)] = (ts_y_nonzero - min_consts[j]) / \
                                             (max_consts[j] - min_consts[j])
    
    data_gen = batcher(x_scaled, y_scaled, batch_size=batch_size, infinite=True)
    
    checkpoint_name = '{}{}_interpolation_share_{}H_G_2_smape.th'.\
                            format(folder, data_type[:-2], i)
    
    print('--- Model ---')
    n_stacks = 30
    net = NBeatsNet(device=device,
                    stack_types=[NBeatsNet.GENERIC_BLOCK] * n_stacks,
                    forecast_length=forecast_length,
                    thetas_dims=[4] * n_stacks,
                    nb_blocks_per_stack=1,
                    backcast_length=backcast_length,
                    hidden_layer_units=512,
                    share_weights_in_stack=True
                    )

    optimiser = optim.Adam(net.parameters())

    def plot_model(x, target, grad_step):
        plot(net, x, target, backcast_length, forecast_length, grad_step)

    losses = fit_smape(net, optimiser, data_gen, plot_model, device, \
                              max_grad_steps, checkpoint_name)
